# %% [markdown]
# # [TEST] Cleaning CSV Master

# %% [markdown]
# # 0. Libraries and Packages

# %%
import numpy as np
import pandas as pd

# %%
file_path = '/Users/salmadanu/Desktop/Skripsi/skripsi-env/narasipal/master_csv/kompas_master.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#        content_PublishedDate            content_editor content_site  \
# 0  3 Januari 2024, 10:46 WIB                   unknown   Kompas.com
# 1  3 Januari 2024, 09:43 WIB         Arini Kusuma Jati   Kompas.com
# 2  3 Januari 2024, 08:12 WIB                   unknown   Kompas.com
# 3  3 Januari 2024, 08:05 WIB  Anneke Sherina Ramadhani   Kompas.com
# 4  3 Januari 2024, 07:17 WIB         Anggie Puspariana   Kompas.com
#
#   content_tags                                      content_title  \
# 0      unknown  Pejabat Senior Hamas Tewas Usai Serangan Drone...
# 1      unknown  Israel Bakal Bela Diri di Kasus Kejahatan Geno...
# 2      unknown  Momen Militer Israel Temukan Berbagai Senjata ...
# 3      unknown  Ribuan Warga Palestina Kembali ke Gaza Utara U...
# 4      unknown  Terperangkap Dalam Perang, Ini yang Dilakukan ...
#
#   content_total_words content_type  \
# 0             unknown        Video
# 1             unknown        Video
# 2             unknown        Video
# 3             unknown        Video
# 4             unknown        Video
#
#                                                  url
# 0  https://video.kompas.com/watch/1135553/pejabat...
# 1  https://video.kompas.com/watch/1135421/israel-...
# 2  https://video.kompas.com/watch/1135211/momen-m...
# 3  https://video.kompas.com/watch/1135209/ribuan-...
# 4  https://video.kompas.com/watch/1135175/terpera...

# %% [markdown]
# # 1. Cleaning Data
# ### Format:
# - `id` = `int`
# - `content_PublishedDate` = `datetime` YYYY-MM-DD HH:MM:SS
# - `content_editor` = `object`
# - `content_site` = `object `Kompas.com
# - `content_tags` = `str`
# - `content_title` = `str`
# - `content_total_words` = `int`
# - `content_type` = `object`
# - `url` = `int`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4575 entries, 0 to 4574
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   content_PublishedDate  1645 non-null   object
#  1   content_editor         1645 non-null   object
#  2   content_site           1645 non-null   object
#  3   content_tags           1645 non-null   object
#  4   content_title          1645 non-null   object
#  5   content_total_words    1645 non-null   object
#  6   content_type           1645 non-null   object
#  7   url                    4575 non-null   object
# dtypes: object(8)
# memory usage: 286.1+ KB

# %% [markdown]
# ## Checking for duplicate rows

# %%
duplicate = df[df.duplicated]
duplicate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89 entries, 2641 to 4019
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   content_PublishedDate  29 non-null     object
#  1   content_editor         29 non-null     object
#  2   content_site           29 non-null     object
#  3   content_tags           29 non-null     object
#  4   content_title          29 non-null     object
#  5   content_total_words    29 non-null     object
#  6   content_type           29 non-null     object
#  7   url                    89 non-null     object
# dtypes: object(8)
# memory usage: 6.3+ KB

# %%
df_clean = df.drop_duplicates()

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4486 entries, 0 to 4574
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   content_PublishedDate  1616 non-null   object
#  1   content_editor         1616 non-null   object
#  2   content_site           1616 non-null   object
#  3   content_tags           1616 non-null   object
#  4   content_title          1616 non-null   object
#  5   content_total_words    1616 non-null   object
#  6   content_type           1616 non-null   object
#  7   url                    4486 non-null   object
# dtypes: object(8)
# memory usage: 315.4+ KB

# %% [markdown]
# ## Standardizing `content_PublishedDate` and extracting `content_title` from `url`
# YYYY-MM-DD HH:MM:SS

# %% [markdown]
# Logic (use regex)
# for all rows in df
# if `content_PublishedDate` has value:
#     if format is not YYYY-MM-DD HH:MM:SS
#         change to YYYY-MM-DD HH:MM:SS based on:
#             4 number sequence = YYYY
#             MM ikutin mapping:
#                 January = 01
#                 February = 02
#             add space
#             2 number sequence = DD
#             erase ,
#             erase WIB
#             HH:MM to HH:SS:00
#     else:
#         keep format
# else:
#     null
#
#
# if `content_title` is NULL:
#     df[content_title] = last part of url (all text from the end before the last '/')
#     remove -
#     make title case

# %%
import pandas as pd
import re
from urllib.parse import urlparse

# %%
month_map = {
    "January": "01", 
    "February": "02", 
    "March": "03", 
    "April": "04",
    "May": "05", 
    "June": "06", 
    "July": "07", 
    "August": "08",
    "September": "09", 
    "October": "10", 
    "November": "11", 
    "December": "12"
}

# %%
df_clean = df.copy()

# Funtion for standardizing datetime
def standardize_date(date_str):
    if pd.isna(date_str):
        return None
    match = re.search(r"(\d{1,2}) (\w+) (\d{4}), (\d{2}):(\d{2}) WIB", date_str)
    if match:
        day, month, year, hour, minute = match.groups()
        return f"{year}-{month_map.get(month, 'XX')}-{int(day):02d} {hour}:{minute}:00"
    return date_str 

# Funtion for extracting judul berita from url
def extract_title_from_url(url):
    if pd.isna(url):
        return None
    path = urlparse(url).path
    last_part = path.rstrip("/").split("/")[-1]
    return last_part.replace("-", " ").title()

# Apply transformations
df_clean.loc[:, "content_PublishedDate"] = df_clean["content_PublishedDate"].apply(standardize_date)
df_clean.loc[:, "content_title"] = df_clean.apply(
    lambda row: extract_title_from_url(row["url"]) if pd.isna(row["content_title"]) else row["content_title"], axis=1
)

df_clean
# Out:
#      content_PublishedDate            content_editor content_site  \
# 0      2024-XX-03 10:46:00                   unknown   Kompas.com
# 1      2024-XX-03 09:43:00         Arini Kusuma Jati   Kompas.com
# 2      2024-XX-03 08:12:00                   unknown   Kompas.com
# 3      2024-XX-03 08:05:00  Anneke Sherina Ramadhani   Kompas.com
# 4      2024-XX-03 07:17:00         Anggie Puspariana   Kompas.com
# ...                    ...                       ...          ...
# 4570   2023-11-29 17:15:00                   unknown   Kompas.com
# 4571   2023-11-29 17:14:00        Aditya Jaya Iswara   Kompas.com
# 4572   2023-11-29 17:13:00                   unknown   Kompas.com
# 4573   2023-11-29 17:09:49              Dani Prabowo   Kompas.com
# 4574   2023-11-29 17:00:00    Adinda Septia Berliana   Kompas.com
#
#                                            content_tags  \
# 0                                               unknown
# 1                                               unknown
# 2                                               unknown
# 3                                               unknown
# 4                                               unknown
# ...                                                 ...
# 4570                                            unknown
# 4571  sejarah Tepi Barat, sejarah wilayah Tepi Barat...
# 4572                                            unknown
# 4573       Israel, Palestina, pemilu, Bentrok di Bitung
# 4574                                            unknown
#
#                                           content_title content_total_words  \
# 0     Pejabat Senior Hamas Tewas Usai Serangan Drone...             unknown
# 1     Israel Bakal Bela Diri di Kasus Kejahatan Geno...             unknown
# 2     Momen Militer Israel Temukan Berbagai Senjata ...             unknown
# 3     Ribuan Warga Palestina Kembali ke Gaza Utara U...             unknown
# 4     Terperangkap Dalam Perang, Ini yang Dilakukan ...             unknown
# ...                                                 ...                 ...
# 4570  Momen Sandera Hamas Lambaikan Tangannya Saat D...             unknown
# 4571  Sejarah Wilayah Tepi Barat dalam Konflik Israe...                2158
# 4572  Dari Podium Sidang PBB, Menlu Retno Suarakan K...             unknown
# 4573  Pasca Bentrokan di Bitung, Kapolri Minta Masya...                 261
# 4574  Jumlah Warga Palestina dan Israel yang Dilepas...             unknown
#
#      content_type                                                url
# 0           Video  https://video.kompas.com/watch/1135553/pejabat...
# 1           Video  https://video.kompas.com/watch/1135421/israel-...
# 2           Video  https://video.kompas.com/watch/1135211/momen-m...
# 3           Video  https://video.kompas.com/watch/1135209/ribuan-...
# 4           Video  https://video.kompas.com/watch/1135175/terpera...
# ...           ...                                                ...
# 4570        Video  https://video.kompas.com/watch/1062854/momen-s...
# 4571     Standard  http://internasional.kompas.com/read/2023/11/2...
# 4572        Video  https://video.kompas.com/watch/1062853/dari-po...
# 4573     Standard  http://nasional.kompas.com/read/2023/11/29/170...
# 4574        Video  https://video.kompas.com/watch/1062844/jumlah-...
#
# [4575 rows x 8 columns]

# %% [markdown]
# ## New dataframe `df_title` with just `content_title`

# %%
df_title = df_clean[['content_title']]
df_title.head()
# Out:
#                                        content_title
# 0  Pejabat Senior Hamas Tewas Usai Serangan Drone...
# 1  Israel Bakal Bela Diri di Kasus Kejahatan Geno...
# 2  Momen Militer Israel Temukan Berbagai Senjata ...
# 3  Ribuan Warga Palestina Kembali ke Gaza Utara U...
# 4  Terperangkap Dalam Perang, Ini yang Dilakukan ...

# %% [markdown]
# ## `df_title` to CSV

# %%
df_title.to_csv('/Users/salmadanu/Desktop/Skripsi/skripsi-env/narasipal/cleaning/title_csv/kompas_titles.csv', index=True)
